# %%
import pandas as pd
import sidetable as stb
import os
import geopandas as gpd
import plotly.express as px
import matplotlib.pyplot as plt

# %% [raw]
# #os.chdir(r'C:\Users\win\AnacondaProjects\0 0 Projects\Project_11\bases')
# os.chdir(r'C:\Users\IVANOV\AnacondaProjects\0 0 Projects\dash_fem\bases')

# %% [markdown]
# ### Filtro "Presunto"

# %%
lista_GOG=[
    #'def98_r','def99_r',
    #'def00_r','def01_r','def02_r','def03_r','def04_r','def05_r',
    #'def06_r','def07_r','def08_r','def09_r','def10_r','def11_r',
    #'def12_r','def13_r',
    #'def14_r',
    #'def15_r','def16_r','def17_r','def18_r','def19_r'
    'def20_r'
          ]

for e in lista_GOG:
    
    base=pd.read_csv('%s.csv'%(e))
    base.drop('Unnamed: 0',1,inplace=True)
    
    # filtros
    base1=base[base.Presunto == 2]
    
    # violencia familiar
    #base2=base1[(base1.Viol_fam == 1)|(base1.Viol_fam == 2)]
    
    # embarazo
    #base3=base2[(base2.Embarazo != 5 )|(base2.Embarazo != 8)]
    
    # condición de embarazo
    #base4=base3[base3.Rel_emb == 1]

    # edad
    #base4= base3[(base3.Edad_g >= 1)&(base3.Edad_g <= 12)]
    
    base1.to_csv('%s_femeninas.csv' %(e))
    print ("Guardado %s_femeninas "%(e))
# Out:
# Guardado def20_r_femeninas
# C:\Users\PRIME\AppData\Local\Temp/ipykernel_17304/3592283409.py:14: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   base.drop('Unnamed: 0',1,inplace=True)

# %%
#################################################################################################

# %% [markdown]
# ### Ajustes

# %% [markdown]
#     re agrupado de variables

# %% [raw]
# import pandas as pd
#
# alv=['def15_r_femeninas','def16_r_femeninas','def17_r_femeninas','def18_r_femeninas','def19_r_femeninas']
# for e in alv:
#     a=pd.read_csv('%s.csv'%(e))
#     #a.columns
#     print(e)
#     print(a.Ocupacion.value_counts().head())
#     print()

# %% [markdown]
# ## replace

# %%
#os.chdir(r'C:\Users\win\AnacondaProjects\0 0 Projects\Project_11\results\\')
#os.chdir(r'C:\Users\IVANOV\AnacondaProjects\0 0 Projects\dash_fem\bases\\')

y_list=[#"def15_r_femeninas","def16_r_femeninas","def17_r_femeninas","def18_r_femeninas","def19_r_femeninas"
       'def20_r_femeninas']
    

for y in y_list:
    base=pd.read_csv("%s.csv"%(y))
    
    ################################################# Reemplaco de categorías-variables
    
    # Edo_civil
    base.Edo_civil.replace(1, "Soltera",inplace=True)
    base.Edo_civil.replace(2, "Divorciada",inplace=True)
    base.Edo_civil.replace(3, "Viuda",inplace=True)
    base.Edo_civil.replace(4, "Unión libre",inplace=True)
    base.Edo_civil.replace(5, "Casada",inplace=True)
    base.Edo_civil.replace(6, "Separada",inplace=True)
    base.Edo_civil.replace(8, "No aplica a menores de 12 años",inplace=True)
    base.Edo_civil.replace(9, "Estado civil no especificado",inplace=True)

    
    # Embarazo
    base.Embarazo.replace(1, "Si, o en fase posterior",inplace=True)
    base.Embarazo.replace(2, "Si, o en fase posterior",inplace=True)
    base.Embarazo.replace(3, "Si, o en fase posterior",inplace=True)
    base.Embarazo.replace(4, "Si, o en fase posterior",inplace=True)
    base.Embarazo.replace(5, "No",inplace=True)
    base.Embarazo.replace(6, "Si, o en fase posterior",inplace=True)
    base.Embarazo.replace(8, "No aplica",inplace=True)
    base.Embarazo.replace(9, "No especificado ",inplace=True)

    # Violencia familia
    base.Viol_fam.replace(1,"Violencia familiar o de fuera",inplace=True)
    base.Viol_fam.replace(2,"Violencia familiar o de fuera",inplace=True)
    base.Viol_fam.replace(8,"No aplica",inplace=True)
    base.Viol_fam.replace(9,"No especificado",inplace=True)
    
    # Ocupacion
    base.Ocupacion.replace(1,"Trabaja",inplace=True)
    base.Ocupacion.replace(2,"Trabaja",inplace=True)
    base.Ocupacion.replace(3,"Trabaja",inplace=True)
    base.Ocupacion.replace(4,"Trabaja",inplace=True)
    base.Ocupacion.replace(5,"Trabaja",inplace=True)
    base.Ocupacion.replace(6,"Trabaja",inplace=True)
    base.Ocupacion.replace(7,"Trabaja",inplace=True)
    base.Ocupacion.replace(8,"Trabaja",inplace=True)
    base.Ocupacion.replace(9,"Trabaja",inplace=True)
    base.Ocupacion.replace(10,"Busca trabajo",inplace=True)
    base.Ocupacion.replace(11,"No trabaja",inplace=True)
    base.Ocupacion.replace(97,"No aplica a menores de 5 años",inplace=True)
    base.Ocupacion.replace(98,"No especificada",inplace=True)
    base.Ocupacion.replace(99,"No especificada",inplace=True)
    
    ## Ocupacion (original)
    #base.Ocupacion.replace(1,"Funcionarios, directores y jefes",inplace=True)
    #base.Ocupacion.replace(2,"Profesionistas y técnicos",inplace=True)
    #base.Ocupacion.replace(3,"Trabajadores auxiliares en Ocupaciones administrativas",inplace=True)
    #base.Ocupacion.replace(4,"Comerciantes, empleados en ventas y agentes de ventas",inplace=True)
    #base.Ocupacion.replace(5,"Trabajadores en servicios personales y vigilancia",inplace=True)
    #base.Ocupacion.replace(6,"Trabajadores en Ocupaciones agrícolas, ganaderas, forestales, caza y pesca",inplace=True)
    #base.Ocupacion.replace(7,"Trabajadores artesanales",inplace=True)
    #base.Ocupacion.replace(8,"Operadores de maquinaria industrial, ensambladores, choferes y conductores de transporte",inplace=True)
    #base.Ocupacion.replace(9,"Trabajadores en Ocupaciones elementales y de apoyo",inplace=True)
    #base.Ocupacion.replace(10,"Busca trabajo",inplace=True)
    #base.Ocupacion.replace(11,"No trabaja",inplace=True)
    #base.Ocupacion.replace(97,"No aplica a menores de 5 años",inplace=True)
    #base.Ocupacion.replace(98,"Ocupaciones insuficientemente especificadas",inplace=True)
    #base.Ocupacion.replace(99,"Ocupación no especificada",inplace=True)

                  
    # Parentesco con el agresor                   
    base.Par_agre.replace(1,"Familia nuclear",inplace=True)
    base.Par_agre.replace(2,"Familia nuclear",inplace=True)
    base.Par_agre.replace(3,"Familia nuclear",inplace=True)
    base.Par_agre.replace(4,"Familia nuclear",inplace=True)
    base.Par_agre.replace(5,"Familia nuclear",inplace=True)
    base.Par_agre.replace(6,"Familia nuclear",inplace=True)
    base.Par_agre.replace(7,"Familia nuclear",inplace=True)
    base.Par_agre.replace(8,"Familia nuclear",inplace=True)
    base.Par_agre.replace(9,"Familia nuclear",inplace=True)
    base.Par_agre.replace(10,"Familia nuclear",inplace=True)
    base.Par_agre.replace(13,"Familia nuclear",inplace=True)
    base.Par_agre.replace(14,"Familia nuclear",inplace=True)
    base.Par_agre.replace(15,"Familia nuclear",inplace=True)
    base.Par_agre.replace(16,"Familia nuclear",inplace=True)
    base.Par_agre.replace(17,"Familia nuclear",inplace=True)
    base.Par_agre.replace(18,"Familia nuclear",inplace=True)
    base.Par_agre.replace(19,"Familia nuclear",inplace=True)
    base.Par_agre.replace(20,"Familia nuclear",inplace=True)
    base.Par_agre.replace(21,"Familia nuclear",inplace=True)
    base.Par_agre.replace(22,"Familia nuclear",inplace=True)
    base.Par_agre.replace(23,"Familia nuclear",inplace=True)
    base.Par_agre.replace(24,"Familia nuclear",inplace=True)
    base.Par_agre.replace(25,"Familia nuclear",inplace=True)
    base.Par_agre.replace(26,"Familia nuclear",inplace=True)
    base.Par_agre.replace(27,"Familia extendida",inplace=True)
    base.Par_agre.replace(28,"Familia extendida",inplace=True)
    base.Par_agre.replace(29,"Familia extendida",inplace=True)
    base.Par_agre.replace(30,"Familia extendida",inplace=True)
    base.Par_agre.replace(31,"Familia extendida",inplace=True)
    base.Par_agre.replace(32,"Familia extendida",inplace=True)
    base.Par_agre.replace(33,"Familia extendida",inplace=True)
    base.Par_agre.replace(34,"Familia extendida",inplace=True)
    base.Par_agre.replace(35,"Familia extendida",inplace=True)
    base.Par_agre.replace(36,"Familia extendida",inplace=True)
    base.Par_agre.replace(37,"Familia extendida",inplace=True)
    base.Par_agre.replace(38,"Familia extendida",inplace=True)
    base.Par_agre.replace(39,"Familia extendida",inplace=True)
    base.Par_agre.replace(40,"Familia extendida",inplace=True)
    base.Par_agre.replace(41,"Familia extendida",inplace=True)
    base.Par_agre.replace(42,"Familia extendida",inplace=True)
    base.Par_agre.replace(44,"Familia extendida",inplace=True)
    base.Par_agre.replace(43,"Familia extendida",inplace=True)
    base.Par_agre.replace(11,"Familia nuclear",inplace=True)
    base.Par_agre.replace(12,"Familia nuclear",inplace=True)
    base.Par_agre.replace(45,"Familia nuclear",inplace=True)
    base.Par_agre.replace(46,"Familia nuclear",inplace=True)
    base.Par_agre.replace(47,"Familia nuclear",inplace=True)
    base.Par_agre.replace(48,"Familia nuclear",inplace=True)
    base.Par_agre.replace(49,"Familia nuclear",inplace=True)
    base.Par_agre.replace(50,"Familia nuclear",inplace=True)
    base.Par_agre.replace(51,"Familia nuclear",inplace=True)
    base.Par_agre.replace(52,"Familia nuclear",inplace=True)
    base.Par_agre.replace(53,"Otra relación",inplace=True)
    base.Par_agre.replace(54,"Otra relación",inplace=True)
    base.Par_agre.replace(55,"Otra relación",inplace=True)
    base.Par_agre.replace(56,"Otra relación",inplace=True)
    base.Par_agre.replace(57,"Otra relación",inplace=True)
    base.Par_agre.replace(58,"Otra relación",inplace=True)
    base.Par_agre.replace(59,"Otra relación",inplace=True)
    base.Par_agre.replace(60,"Otra relación",inplace=True)
    base.Par_agre.replace(61,"Otra relación",inplace=True)
    base.Par_agre.replace(62,"Otra relación",inplace=True)
    base.Par_agre.replace(63,"Otra relación",inplace=True)
    base.Par_agre.replace(64,"Otra relación",inplace=True)
    base.Par_agre.replace(65,"Otra relación",inplace=True)
    base.Par_agre.replace(66,"Otra relación",inplace=True)
    base.Par_agre.replace(67,"Otra relación",inplace=True)
    base.Par_agre.replace(68,"Otra relación",inplace=True)
    base.Par_agre.replace(69,"Otra relación",inplace=True)
    base.Par_agre.replace(70,"Otra relación",inplace=True)
    base.Par_agre.replace(71,"Sin parentesco",inplace=True)
    base.Par_agre.replace(72,"Ninguno",inplace=True)
    base.Par_agre.replace(99,"No especificado",inplace=True)
    
    # Lugar
    base.Lugar.replace(1,"Vía pública",inplace=True)
    base.Lugar.replace(2,"Vía pública",inplace=True)
    base.Lugar.replace(3,"Vía pública",inplace=True)
    base.Lugar.replace(4,"Vía pública",inplace=True)
    base.Lugar.replace(5,"Vía pública",inplace=True)
    base.Lugar.replace(6,"Vía pública",inplace=True)
    base.Lugar.replace(7,"Vía pública",inplace=True)
    base.Lugar.replace(8,"Vía pública",inplace=True)
    base.Lugar.replace(9,"Vía pública",inplace=True)
    base.Lugar.replace(10,"Vía pública",inplace=True)
    base.Lugar.replace(11,"Hogar",inplace=True)
    base.Lugar.replace(12,"Otro lugar",inplace=True)
    base.Lugar.replace(99,"No especificado",inplace=True)
                      
    # Escolaridad
    base.Escolaridad.replace(1,"Sin escolaridad",inplace=True)
    base.Escolaridad.replace(2,"Preescolar",inplace=True)
    base.Escolaridad.replace(3,"Primaria incompleta",inplace=True)
    base.Escolaridad.replace(4,"Primaria completa",inplace=True)
    base.Escolaridad.replace(5,"Secundaria incompleta",inplace=True)
    base.Escolaridad.replace(6,"Secundaria completa",inplace=True)
    base.Escolaridad.replace(7,"Bachillerato o Preparatoria incompleto",inplace=True)
    base.Escolaridad.replace(8,"Bachillerato o Preparatoria completo",inplace=True)
    base.Escolaridad.replace(9,"Profesional",inplace=True)
    base.Escolaridad.replace(10,"Posgrado",inplace=True)
    base.Escolaridad.replace(88,"No aplica a menores de 3 años",inplace=True)
    base.Escolaridad.replace(99,"No especificado",inplace=True)

    # Area urbana
    base.Area_urb.replace(1,"Urbano",inplace=True)
    base.Area_urb.replace(2,"Rural",inplace=True)
    base.Area_urb.replace(9,"No especificado",inplace=True)
                      
    # Edad agrupada
    base.Edad_g.replace(1,"Menor 5 años",inplace=True)
    base.Edad_g.replace(2,"Menor 5 años",inplace=True)
    base.Edad_g.replace(3,"Menor 5 años",inplace=True)
    base.Edad_g.replace(4,"Menor 5 años",inplace=True)
    base.Edad_g.replace(5,"Menor 5 años",inplace=True)
    base.Edad_g.replace(6,"De 5 a 14 años",inplace=True)
    base.Edad_g.replace(7,"De 5 a 14 años",inplace=True)
    base.Edad_g.replace(8,"De 15 a 19 años",inplace=True)
    base.Edad_g.replace(9,"De 20 a 39 años",inplace=True)
    base.Edad_g.replace(10,"De 20 a 39 años",inplace=True)
    base.Edad_g.replace(11,"De 20 a 39 años",inplace=True)
    base.Edad_g.replace(12,"De 20 a 39 años",inplace=True)
    base.Edad_g.replace(13,"De 40 a 55 años",inplace=True)
    base.Edad_g.replace(14,"De 40 a 55 años",inplace=True)
    base.Edad_g.replace(15,"De 40 a 55 años",inplace=True)
    base.Edad_g.replace(16,"De 55 a 74 años",inplace=True)
    base.Edad_g.replace(17,"De 55 a 74 años",inplace=True)
    base.Edad_g.replace(18,"De 55 a 74 años",inplace=True)
    base.Edad_g.replace(19,"De 55 a 74 años",inplace=True)
    base.Edad_g.replace(20,"De 75 a 94 años",inplace=True)
    base.Edad_g.replace(21,"De 75 a 94 años",inplace=True)
    base.Edad_g.replace(22,"De 75 a 94 años",inplace=True)
    base.Edad_g.replace(23,"De 95 y más",inplace=True)
    base.Edad_g.replace(24,"De 95 y más",inplace=True)
    base.Edad_g.replace(25,"De 95 y más",inplace=True)
    base.Edad_g.replace(26,"De 95 y más",inplace=True)
    base.Edad_g.replace(27,"De 95 y más",inplace=True)
    base.Edad_g.replace(28,"De 95 y más",inplace=True)
    base.Edad_g.replace(29,"De 95 y más",inplace=True)
    base.Edad_g.replace(30,"Edad no  especificada",inplace=True)

    base.to_csv('%s.csv'%(y))                       
                           
    #base.to_csv("%s.csv"%(y))
    print("Guardado",y)
# Out:
# Guardado def20_r_femeninas

# %% [raw]
# base_vfam=base.stb.freq(['Viol_fam'])
# base_vfam_f=base_vfam[base_vfam.Viol_fam=='Hubo violencia familiar']
# base_vfam_f

# %% [markdown]
# ### Lopp stb.freq( )

# %%
### loop

year_list=[#'def15_r_femeninas','def16_r_femeninas','def17_r_femeninas','def18_r_femeninas','def19_r_femeninas'
'def20_r_femeninas']

for e in year_list:
    
    #os.chdir(r'C:\Users\win\AnacondaProjects\0 0 Projects\Project_11\results\\')
    #os.chdir(r'C:\Users\IVANOV\AnacondaProjects\0 0 Projects\dash_fem\bases\\')
    
    base = pd.read_csv('%s.csv' %(e))
    base.drop('Unnamed: 0',1,inplace=True)
    tot_anual=base.Presunto.sum()
    
    ################################# Identificadores
    # ENTIDADES
    base_ent0 =base.stb.freq(['Entidad'])
    ent1=base_ent0.iloc[0]['Entidad']
    ent2=base_ent0.iloc[1]['Entidad']
    ent3=base_ent0.iloc[2]['Entidad']
    ent4=base_ent0.iloc[3]['Entidad']
    ent5=base_ent0.iloc[4]['Entidad']  
    #valores 
    ent1p=(base_ent0.iloc[0]['percent']).round(1)
    ent2p=(base_ent0.iloc[1]['percent']).round(1)
    ent3p=(base_ent0.iloc[2]['percent']).round(1)
    ent4p=(base_ent0.iloc[3]['percent']).round(1)
    ent5p=(base_ent0.iloc[4]['percent']).round(1)
    
    # ESCOLARIDAD
    base_esc =base.stb.freq(['Escolaridad'])
    esc1=base_esc.iloc[0]['Escolaridad']
    esc2=base_esc.iloc[1]['Escolaridad']
    esc3=base_esc.iloc[2]['Escolaridad']
    #valores 
    esc1p=(base_esc.iloc[0]['percent']).round(1)
    esc2p=(base_esc.iloc[1]['percent']).round(1)
    esc3p=(base_esc.iloc[2]['percent']).round(1)
    
    ## ESTADO CIVIl
    base_ecivil=base.stb.freq(['Edo_civil'])
    civil1=base_ecivil.iloc[0]['Edo_civil']
    civil2=base_ecivil.iloc[1]['Edo_civil']
    civil3=base_ecivil.iloc[2]['Edo_civil']
    civil4=base_ecivil.iloc[3]['Edo_civil']
    ##valores 
    civil1p=(base_ecivil.iloc[0]['percent']).round(1)
    civil2p=(base_ecivil.iloc[1]['percent']).round(1)
    civil3p=(base_ecivil.iloc[2]['percent']).round(1)
    civil4p=(base_ecivil.iloc[3]['percent']).round(1)
    
    # LUGAR
    base_lug=base.stb.freq(['Lugar'])
    base_lug_f=base_lug[base_lug.Lugar=="Vía pública"].reset_index()
    lug1=base_lug_f.iloc[0]['Lugar']           
    #valores 
    lug1p=(base_lug_f.iloc[0]['percent']).round(1)
    
    base_lug_f1=base_lug[base_lug.Lugar=="Hogar"].reset_index()
    lug2=base_lug_f1.iloc[0]['Lugar']
    lug2p=(base_lug_f1.iloc[0]['percent']).round(1)

    # EMBARAZO
    base_emb=base.stb.freq(['Embarazo'])
    emb3=base_emb.iloc[0]['Embarazo']
    #valores 
    emb3p=(base_emb.iloc[0]['percent']).round(1)
    #filtro
    base_emb_f=base_emb[base_emb.Embarazo=='Si, o en fase posterior']
    emb1=base_emb_f.iloc[0]['Embarazo']
    #valores 
    emb1p=(base_emb_f.iloc[0]['percent']).round(1)
    #filtro
    base_emb_f2=base_emb[base_emb.Embarazo=='No']
    emb2=base_emb_f2.iloc[0]['Embarazo']
    #valores 
    emb2p=(base_emb_f2.iloc[0]['percent']).round(1)

    
    # AREA URBANA-RURAL
    base_area=base.stb.freq(['Area_urb'])
    area1=base_area.iloc[0]['Area_urb']
    #area2=base_area.iloc[1]['Embarazo']
    #valores
    area1p=(base_area.iloc[0]['percent']).round(1)
    #area2p=base_area.iloc[1]['percent']
    
    # VIOLENCIA FAMILIAR
    base_vfam=base.stb.freq(['Viol_fam'])
    vfam2=base_vfam.iloc[0]['Viol_fam']
    #valores
    vfam2p=(base_vfam.iloc[0]['percent']).round(1)
    #filtro
    base_vfam_f=base_vfam[base_vfam.Viol_fam=='Violencia familiar o de fuera']
    vfam1=base_vfam_f.iloc[0]['Viol_fam']
    #valores
    vfam1p=(base_vfam_f.iloc[0]['percent']).round(1)
    
    # EDAD AGRUPADA
    base_eg=base.stb.freq(['Edad_g'])
    edagru1=base_eg.iloc[0]['Edad_g']
    edagru2=base_eg.iloc[1]['Edad_g']
    edagru3=base_eg.iloc[2]['Edad_g']
    edagru4=base_eg.iloc[3]['Edad_g']
    edagru5=base_eg.iloc[4]['Edad_g']
    #valores
    edagru1p=(base_eg.iloc[0]['percent']).round(1)
    edagru2p=(base_eg.iloc[1]['percent']).round(1)
    edagru3p=(base_eg.iloc[2]['percent']).round(1)
    edagru4p=(base_eg.iloc[3]['percent']).round(1)
    edagru5p=(base_eg.iloc[4]['percent']).round(1)
    
    # ACTIVIDAD
    base_ac=base.stb.freq(['Ocupacion'])
    ocu1=base_ac.iloc[0]['Ocupacion']
    ocu2=base_ac.iloc[1]['Ocupacion']
    ocu3=base_ac.iloc[2]['Ocupacion']
    #valores
    ocu1p=(base_ac.iloc[0]['percent']).round(1)
    ocu2p=(base_ac.iloc[1]['percent']).round(1)
    ocu3p=(base_ac.iloc[2]['percent']).round(1)
    
    
    # PAReNTESCO CON EL AGRESOR
    #base_pare=base[base.Par_agre!='ninguno']
    base_pare_f=base.stb.freq(['Par_agre'])
    paren1=base_pare_f.iloc[0]['Par_agre']
    paren2=base_pare_f.iloc[1]['Par_agre']
    paren3=base_pare_f.iloc[2]['Par_agre']
    #valores
    paren1p=(base_pare_f.iloc[0]['percent']).round(1)
    paren2p=(base_pare_f.iloc[1]['percent']).round(1)
    paren3p=(base_pare_f.iloc[2]['percent']).round(1)
    
    ###############################################################################
    
    
     ################################# Agrupamiento de identificadores
    Agrupado_ids = pd.DataFrame(
        {'Variable':[     
            "Total anual",
            "Entidad",
            ent1,
            ent2,
            ent3,
            ent4,
            ent5,            
            "Escolaridad",
            esc1,
            esc2,
            esc3,
            "Lugar",
            lug1,
            lug2,
            #lug3, 
            "Embarazo",
            emb1,
            emb2,
            emb3,
            "Area Urbana",
            area1,    
            "Violencia Familiar",
            vfam1,
            vfam2,    
            "Edad Agrupada",
            edagru1,
            edagru2,
            edagru3,
            edagru4,
            edagru5,
            "Ocupación",
            ocu1,
            ocu2,
            ocu3,
            "Parentesco c/agresor",
            paren1,
            paren2,
            paren3,
            'Estado Civil',
            civil1,
            civil2,
            civil3,
            civil4,
   
    ],'Valor':[
        
        tot_anual,
        "Entidad_%",
        ent1p,
        ent2p,
        ent3p,
        ent4p,
        ent5p,          
        "Escolaridad_%",
        esc1p,
        esc2p,
        esc3p,
        "Lugar_%",
        lug1p,
        lug2p,
        #lug3p, 
        "Embarazo_%",
        emb1p,
        emb2p,
        emb3p,    
        "Area Urbana_%",
        area1p,    
        "Violencia Familiar_%",
        vfam1p,
        vfam2p,    
        "Edad Agrupada_%",
        edagru1p,
        edagru2p,
        edagru3p,
        edagru4p,
        edagru5p,
        "Ocupación_%",
        ocu1p,
        ocu2p,
        ocu3p,
        "Parentesco c/agresor_%",
        paren1p,
        paren2p,
        paren3p,
        'Civil_%',
        civil1p,
        civil2p,
        civil3p,
        civil4p,
                ]})
    
    #os.chdir(r'C:\Users\win\AnacondaProjects\0 0 Projects\Project_11\results')
    #os.chdir(r'C:\Users\IVANOV\AnacondaProjects\0 0 Projects\dash_fem\resultados')
    
    Agrupado_ids.to_csv("%s_tabla de datos.csv" %(e))
    #Agrupado_ids.to_excel("%s_tabla de datos.xlsx" %(e))
    print("Guarado %s csv"%(e))
# Out:
# Guarado def20_r_femeninas csv
# C:\Users\PRIME\AppData\Local\Temp/ipykernel_17304/423792706.py:12: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   base.drop('Unnamed: 0',1,inplace=True)

# %%
base_eg
# Out:
#                   Edad_g  count    percent  cumulative_count  \
# 0        De 20 a 39 años   1682  43.205754              1682
# 1        De 40 a 55 años    733  18.828667              2415
# 2        De 35 a 39 años    385   9.889545              2800
# 3        De 15 a 19 años    375   9.632674              3175
# 4        De 55 a 74 años    309   7.937323              3484
# 5  Edad no  especificada    159   4.084254              3643
# 6         De 5 a 14 años     92   2.363216              3735
# 7           Menor 5 años     81   2.080658              3816
# 8        De 75 a 94 años     70   1.798099              3886
# 9            De 95 y más      7   0.179810              3893
#
#    cumulative_percent
# 0           43.205754
# 1           62.034421
# 2           71.923966
# 3           81.556640
# 4           89.493964
# 5           93.578217
# 6           95.941433
# 7           98.022091
# 8           99.820190
# 9          100.000000

# %%
#########################################################################################################

# %% [markdown]
# # Mapas shp (loop)

# %%
year_list=['def15_r_femeninas',
           'def16_r_femeninas',
           'def17_r_femeninas',
           'def18_r_femeninas',
           'def19_r_femeninas'
          ]


for e in year_list:
    
    os.chdir(r'C:\Users\win\AnacondaProjects\0 0 Projects\Project_11\bases')
    #os.chdir(r'C:\Users\IVANOV\AnacondaProjects\0 0 Projects\dash_fem\bases')
    
    base = pd.read_csv('%s.csv' %(e))
    
    base.drop('Unnamed: 0',1,inplace=True)
    
    # ENTIDADES
    base_ent0 =base.stb.freq(['Entidad'])
    
# Ruta archivo shp
    #os.chdir(r'C:\Users\win\AnacondaProjects\0 0 Projects\Project_11\bases')     #_____________________Ruta Fe
    os.chdir(r'C:\Users\IVANOV\AnacondaProjects\0 0 Projects\dash_fem\bases\shp') #_____________________Ruta Wi
    #os.chdir(r'C:\Users\win\AnacondaProjects\0 0 Projects\Project_11\bases')     #_____________________Ruta Ae

    geo_df=gpd.read_file('México_Estados.shp')
    
    geo_df.replace(['Coahuila','Distrito Federal','Michoacán',"Veracruz"],
                   #por
                   ['Coahuila de Zaragoza','Ciudad de México','Michoacán de Ocampo','Veracruz de Ignacio de la Llave'],
                   inplace=True, )
    
    # Merge para entidades
    concat0 = geo_df.merge(base_ent0, #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<____cambiar año 
                       left_on= "ESTADO", right_on="Entidad", how= "right")#.sort_values('count', ascending=False).head(3)
    
    concat1 = geo_df.merge(base_ent0, #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<____cambiar año 
                       left_on= "ESTADO", right_on="Entidad", how= "right").sort_values('count', ascending=False).head(5)
    
    a1= concat0.plot("count",  
                 color='white',
                 #cmap= "Oranges", 
                 
             legend=False, 
             linewidth=.1, 
             edgecolor= "black", 
             figsize=(3,3))
    
    
    concat1.plot(ax=a1 , #"count",
        color='brown',# cmap= "Oranges", 
             linewidth=.2, 
             edgecolor= "black", 
             figsize=(3,3))
    
    plt.axis("off")
    
    #os.chdir(r'C:\Users\win\AnacondaProjects\0 0 Projects\Project_11\bases')      #_____________________Ruta Fe
    os.chdir(r'C:\Users\IVANOV\AnacondaProjects\0 0 Projects\dash_fem\resultados') #_____________________Ruta Wi
    #os.chdir(r'C:\Users\win\AnacondaProjects\0 0 Projects\Project_11\bases')      #_____________________Ruta Ae

    plt.savefig("Mapa feminicidio %s.jpeg" %(e), dpi= 120),# fontsize=4)
    print("Guardado %s"%(e))
    plt.show()
    
    
    #mapa.to_image("mapa2018.jpeg")
    #print("Guardado")
    #mapa.show()

# %% [markdown]
# ## mapas shp (1)

# %% [raw]
# os.chdir(r'C:\Users\IVANOV\AnacondaProjects\0 0 Projects\dash_fem\bases\shp')
#
# geo_df=gpd.read_file('México_Estados.shp')
# geo_df

# %%
os.chdir(r'C:\Users\IVANOV\AnacondaProjects\0 0 Projects\dash_fem\bases')
    
base = pd.read_csv('def17_r_femeninas.csv')
base_ent0 =base.stb.freq(['Entidad'])
base_ent0.head(5)

# %% [markdown]
# ### Hoyo de Mel (pendiente)

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/Aeelen-Miranda/exercises_pythoncitos/master/mexico.json') as response:
    counties = json.load(response)
counties["features"][0]

# Creacion de geodataframe
geo_df = gpd.GeoDataFrame.from_features(counties["features"])

geo_df.replace(['Coahuila','Distrito Federal','Michoacán',"Veracruz"],
               #por
               ['Coahuila de Zaragoza','Ciudad de México','Michoacán de Ocampo','Veracruz de Ignacio de la Llave'],
               inplace=True)

# Merge para entidades
concat0 = geo_df.merge(femi15_21, #_______________________________________cambiar año 
                       left_on= "name", right_on="Entidad", how= "right")

# %%
mapa =  px.choropleth_mapbox(concat2,
                                   geojson=concat2.geometry,
                                   locations=concat2.index,
                                   color= "Total2020",   
                                   center={"lat": 23.88234, "lon": -102.28259},
                                   mapbox_style="white-bg",
                                   zoom= 2,
                                   opacity=.6,
                                   color_continuous_scale=px.colors.sequential.Reds,
                                   range_color=[0,150])
mapa.update_layout(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)',
    height=120, width = 200, margin={"r":0.3,"t":0.3,"l":0.3,"b":0.3},
                      coloraxis_showscale=False)

#mapa.write_image("mapa2020.jpeg")
print("Guardado")
mapa.show()
